# %%
import pandas as pd
data= pd.read_csv("25.csv")
data2= pd.read_csv("fitnessData.csv")

data
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0   2017-10-06        5464   200              181               5
# 1   2017-10-07        6041   100              197               8
# 2   2017-10-08          25   100                0               5
# 3   2017-10-09        5461   100              174               4
# 4   2017-10-10        6915   200              223               5
# ..         ...         ...   ...              ...             ...
# 91  2018-01-05         133   100                4               2
# 92  2018-01-06         153   300                0               8
# 93  2018-01-07         500   200                0               5
# 94  2018-01-08        2127   200                0               5
# 95  2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# ...

# %%
data2
# Out:
#                            Timestamp    Your name  Your gender      Your age   \
# 0    2019/07/03 11:48:07 PM GMT+5:30       Parkavi       Female      19 to 25
# 1    2019/07/03 11:51:22 PM GMT+5:30      Nithilaa       Female      19 to 25
# 2    2019/07/03 11:56:28 PM GMT+5:30     Karunya v       Female      15 to 18
# 3     2019/07/04 5:43:35 AM GMT+5:30       Anusha        Female      15 to 18
# 4     2019/07/04 5:44:29 AM GMT+5:30      Nikkitha       Female      19 to 25
# ..                               ...           ...          ...           ...
# 540   2019/07/09 7:46:49 PM GMT+5:30         Kousi       Female  40 and above
# 541   2019/07/09 8:20:48 PM GMT+5:30       Dhanuja       Female  40 and above
# 542  2019/07/12 11:22:18 AM GMT+5:30    Abhinaya V       Female      19 to 25
# 543   2019/07/15 1:48:25 PM GMT+5:30      Vishnu S         Male      19 to 25
# 544   2019/07/21 8:54:46 PM GMT+5:30  Mary Presley       Female  40 and above
#
# ...

# %%
#Individual person analysis.

# %%
data.sort_values(by ='mood', ascending =False)
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 48  2017-11-23        6930   300              234               6
# 49  2017-11-24        5195   300              167               5
# 34  2017-11-09        4683   300              154               9
# 35  2017-11-10        4033   300              137               5
# 36  2017-11-11        6314   300              193               6
# ..         ...         ...   ...              ...             ...
# 72  2017-12-17        1696   100               55               4
# 15  2017-10-21        2822   100               86               6
# 14  2017-10-20        1580   100               49               5
# 5   2017-10-11        4545   100              149               6
# 10  2017-10-16        3148   100              101               8
#
#     bool_of_active  weight_kg
# 48               0         64
# 49               0         64
# 34               0         64
# 35               0         64
# ...

# %%
data.sort_values(by ='hours_of_sleep', ascending =False)
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 34  2017-11-09        4683   300              154               9
# 1   2017-10-07        6041   100              197               8
# 10  2017-10-16        3148   100              101               8
# 21  2017-10-27         202   200                6               8
# 59  2017-12-04        2725   300               86               8
# ..         ...         ...   ...              ...             ...
# 80  2017-12-25         518   100               16               3
# 64  2017-12-09        2909   200               93               3
# 89  2018-01-03        2599   200               84               2
# 91  2018-01-05         133   100                4               2
# 33  2017-11-08        4068   300              131               2
#
#     bool_of_active  weight_kg
# 34               0         64
# 1                0         66
# 10               0         65
# 21               0         64
# ...

# %%
sortedByHourSleept = data.groupby(by=["hours_of_sleep"]).size()
step_count = data.groupby(by=["step_count"]).size()
mood = data.groupby(by=["mood"]).size()

# %%
sortedByHourSleept
sleepHours = pd.DataFrame({'sleepHours':sortedByHourSleept.index, 'days':sortedByHourSleept.values})
stepDays = pd.DataFrame({'steps':step_count.index, 'days':step_count.values})
moodDays = pd.DataFrame({'mood':mood.index, 'days':mood.values})

# %%
sleepHours.plot(x ='sleepHours', y='days', kind = 'line', figsize=(20, 10), title ='SleepHoursPerDays')

# %%
stepDays.plot(x ='steps', y='days', kind = 'scatter', figsize=(20, 10), title ='StepsByDays')

# %%
moodDays.plot(x ='mood', y='days', kind = 'scatter', figsize=(20, 10), title ='MoodByDays')

# %%
print(data2.columns)
# Out:
# Index(['Timestamp', 'Your name ', 'Your gender ', 'Your age ',
#        'How important is exercise to you ?',
#        'How do you describe your current level of fitness ?',
#        'How often do you exercise?',
#        'What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)',
#        'What form(s) of exercise do you currently participate in ?                        (Please select all that apply)',
#        'Do you exercise ___________ ?',
#        'What time if the day do you prefer to exercise?',
#        'How long do you spend exercising per day ?',
#        'Would you say you eat a healthy balanced diet ?',
#        'What prevents you from eating a healthy balanced diet, If any?                         (Please select all that apply)',
#        'How healthy do you consider yourself?',
#        'Have you ever recommended your friends to follow a fitness routine?',
#        'Have you ever purchased a fitness equipment?',
# ...

# %%
uniqueReasonForNotTraining = data2['What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)'].unique()
typesOfExercises = data2['What form(s) of exercise do you currently participate in ?                        (Please select all that apply)'].unique()
timeOfTraining = data2['What time if the day do you prefer to exercise?'].unique()

# %%
reasons = data2.groupby(by=['What barriers, if any, prevent you from exercising more regularly?           (Please select all that apply)']).size()

# %%
reasonsRepetitions = pd.DataFrame({'reason':reasons.index, 'repetitions':reasons.values})

# %%
sortedReasons = reasonsRepetitions.sort_values(by='repetitions', ascending = False)
limitedSortedReason = sortedReasons[:9]

# %%
plot = limitedSortedReason.plot.pie(y='repetitions',labels=limitedSortedReason['reason'], figsize=(15, 15), title="Mainly reason of not exercising")

# %%
uniqueReasonForNotTraining
# Out:
# array(["I don't have enough time;I can't stay motivated",
#        "I don't have enough time;I'll become too tired",
#        "I can't stay motivated", "I don't have enough time",
#        'I exercise regularly with no barriers',
#        "I don't really enjoy exercising",
#        "I can't stay motivated;I don't really enjoy exercising",
#        "I don't have enough time;I can't stay motivated;I'll become too tired;I don't really enjoy exercising",
#        "I don't have enough time;I exercise regularly with no barriers",
#        "I don't have enough time;I can't stay motivated;I'll become too tired;Less stamina",
#        "I don't have enough time;I'll become too tired;I have an injury",
#        "I don't have enough time;I'll become too tired;I don't really enjoy exercising",
#        "I'll become too tired",
#        "I don't have enough time;I can't stay motivated;I'll become too tired;I have an injury",
#        "I'll become too tired;I don't really enjoy exercising",
# ...

# %%
typesOfExercises
# Out:
# array(["I don't really exercise", 'Walking or jogging;Swimming',
#        'Walking or jogging', 'Walking or jogging;Gym;Lifting weights',
#        'Walking or jogging;Yoga', 'Gym;Team sport', 'Gym',
#        'Walking or jogging;Team sport',
#        "Walking or jogging;I don't really exercise",
#        'Walking or jogging;Gym', 'Team sport', 'Zumba dance', 'Yoga',
#        'Walking or jogging;Gym;Lifting weights;Team sport',
#        'Walking or jogging;Gym;Yoga;Lifting weights', 'Gym;Swimming',
#        'Gym;Lifting weights;Team sport',
#        'Walking or jogging;Swimming;Lifting weights',
#        'Walking or jogging;Gym;Yoga',
#        'Walking or jogging;Zumba dance;Team sport',
#        'Walking or jogging;Zumba dance', 'Gym;Swimming;Lifting weights',
#        "Team sport;I don't really exercise",
#        'Walking or jogging;Lifting weights',
#        'Walking or jogging;Yoga;Team sport', 'Swimming',
#        'Gym;Lifting weights', 'Walking or jogging;Gym;Swimming',
# ...

# %%
timeOfTraining
# Out:
# array(['Early morning', 'Evening', 'Afternoon'], dtype=object)

# %%
activities = data2.groupby(by=['What form(s) of exercise do you currently participate in ?                        (Please select all that apply)']).size()
activitiesTypes = pd.DataFrame({'activity':activities.index, 'repetitions':activities.values})

# %%
sortedActivities = activitiesTypes.sort_values(by='repetitions', ascending = False)
limitedSortedActivities = sortedActivities[:9]

# %%
plot = limitedSortedActivities.plot.pie(y='repetitions',labels=limitedSortedActivities['activity'], figsize=(15, 15), title="Mainly activities types")

# %%
motivation = data2.groupby(by=['What motivates you to exercise?         (Please select all that applies )']).size()
motivationDf = pd.DataFrame({'motivation':motivation.index, 'repetitions':motivation.values})

# %%
sorted = motivationDf.sort_values(by='repetitions', ascending=False)

# %%
plot = limitedSortedActivities.plot.pie(y='repetitions',labels=sorted['motivation'], figsize=(15, 15), title="Mainly motivation")
